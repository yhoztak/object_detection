# %%
from __future__ import print_function

from osgeo import gdal
import rasterio
import pandas as pd
import os 
import boto3

# %%
try:
    os.makedirs("images/niihau", 0755)  
except OSError:
    print("folder already exists")

try:
    os.makedirs("niihau", 0755)  
except OSError:
    print("folder already exists")

# %%
root_folder = os.getcwd()
root_folder = "/tmp"
print(root_folder)
# Out:
# /tmp

# %%
not_default_keys = True

if not_default_keys:
    s3_client = boto3.client('s3',
                aws_access_key_id=os.environ.get('hawaii_debris_access_key'),
                aws_secret_access_key=os.environ.get('hawaii_debris_secret_key'))
    s3_resource = boto3.resource('s3',aws_access_key_id=os.environ.get('hawaii_debris_access_key'),
                aws_secret_access_key=os.environ.get('hawaii_debris_secret_key'))
else:
    s3_client = boto3.client('s3')
    s3_resource = boto3.resource('s3')
    
    
bucket_name = 'hawaii-marine-debris'
file_path_template = "{}/jpg/{}"
downloaded_tile = set()
csv_rows = []
islands= ['niihau']#'lanai','bigisland',''
local_tmp_folder = "/tmp/{}"

annotatino_s3key_path = "{island}/annotations.csv"
geojson_keys = [
    "niihau/final_marine_debris_database_NI_UTM4N_boxes.geojson",
    "niihau/niihau_tileindex.geojson",    
]


s3_resource.Bucket(bucket_name).download_file("niihau/final_marine_debris_database_NI_UTM4N_boxes.geojson", "{}/final_marine_debris_database_NI_UTM4N_boxes.geojson".format(root_folder))
s3_resource.Bucket(bucket_name).download_file("niihau/niihau_tileindex.geojson", "{}/niihau_tileindex.geojson".format(root_folder))
s3_resource.Bucket(bucket_name).download_file("niihau/annotations.csv", "{}/niihau/annotations.csv".format(root_folder))

# %%
s3_resource.Bucket(bucket_name).download_file("niihau/annotations.csv", "{}/niihau/annotations.csv".format(root_folder))
existing_annotation_df = pd.read_csv("{}/niihau/annotations.csv".format(root_folder))
existing_annotation_df['file_path'] = existing_annotation_df['s3_key'].replace({'niihau/jpg': '{}/niihau/images'.format(root_folder)}, inplace=False, regex=True)
existing_annotation_df
# Out:
#                            s3_key   x0   y0   x1   y1 label  \
# 0     niihau/jpg/1_1920_06_12.jpg  940  393  990  343     P
# 1     niihau/jpg/1_1920_06_13.jpg  140  393  190  343     P
# 2     niihau/jpg/1_1920_07_13.jpg  242  529  292  479     P
# 3     niihau/jpg/1_1920_07_12.jpg  638  801  738  701     P
# 4     niihau/jpg/1_1920_08_13.jpg  187  133  237   83     P
# 5     niihau/jpg/1_1920_05_11.jpg  528  991  578  941     P
# 6     niihau/jpg/1_1920_06_11.jpg  528  191  578  141     P
# 7     niihau/jpg/1_1920_08_12.jpg  913  376  963  326     P
# 8     niihau/jpg/1_1920_08_14.jpg  184  659  234  609     P
# 9     niihau/jpg/1_1920_07_14.jpg  326  995  376  945     P
# 10    niihau/jpg/1_1920_08_15.jpg  158  681  208  631     P
# 11    niihau/jpg/1_1920_07_15.jpg  374  863  424  813     P
# 12    niihau/jpg/1_1920_09_15.jpg  664  626  714  576     P
# 13    niihau/jpg/1_1920_09_16.jpg  195  598  295  498     P
# 14    niihau/jpg/1_1920_08_16.jpg  208  325  308  225     P
# 15    niihau/jpg/1_1920_07_16.jpg  111  958  211  858     P
# 16    niihau/jpg/1_1920_05_15.jpg  870  922  920  872     P
# 17    niihau/jpg/1_1920_05_16.jpg   70  922  120  872     P
# 18    niihau/jpg/1_1920_06_15.jpg  870  122  920   72     P
# 19    niihau/jpg/1_1920_06_16.jpg   70  122  120   72     P
# 20    niihau/jpg/1_1920_08_17.jpg  161  991  211  941     P
# 21    niihau/jpg/1_1920_09_17.jpg  161  191  211  141     P
# 22    niihau/jpg/1_1920_07_17.jpg    0  691  100  591     P
# 23    niihau/jpg/1_1920_06_17.jpg  767  841  817  791     P
# 24    niihau/jpg/1_1920_10_17.jpg  290  178  340  128     P
# 25    niihau/jpg/1_1920_08_18.jpg  294  411  344  361     P
# 26    niihau/jpg/1_1920_05_22.jpg  685  904  735  854     P
# 27    niihau/jpg/1_1920_06_22.jpg  685  104  735   54     P
# 28    niihau/jpg/2_1747_24_10.jpg  344  750  394  700     P
# 29    niihau/jpg/1_1920_05_23.jpg  222  712  272  662     P
# ...                           ...  ...  ...  ...  ...   ...
# 2399  niihau/jpg/1_1546_32_04.jpg  179  218  229  168     P
# 2400  niihau/jpg/1_1546_29_04.jpg  883  963  933  913     P
# 2401  niihau/jpg/1_1546_29_05.jpg   83  963  133  913     P
# 2402  niihau/jpg/1_1546_30_04.jpg  883  163  933  113     P
# 2403  niihau/jpg/1_1546_30_05.jpg   83  163  133  113     P
# 2404  niihau/jpg/1_1546_26_07.jpg  939  890  989  840     P
# 2405  niihau/jpg/1_1546_26_08.jpg  139  890  189  840     P
# 2406  niihau/jpg/1_1546_27_07.jpg  939   90  989   40     P
# 2407  niihau/jpg/1_1546_27_08.jpg  139   90  189   40     P
# 2408  niihau/jpg/1_1546_25_09.jpg  611  753  661  703     P
# 2409  niihau/jpg/1_1546_25_11.jpg  648  779  748  679     P
# 2410  niihau/jpg/1_1546_25_12.jpg   35  567   85  517     P
# 2411  niihau/jpg/1_1546_25_10.jpg  803  622  853  572     P
# 2412  niihau/jpg/1_1546_24_12.jpg  738  586  788  536     P
# 2413  niihau/jpg/1_1546_23_12.jpg  901  956  951  906     P
# 2414  niihau/jpg/1_1546_23_13.jpg  101  956  151  906     P
# 2415  niihau/jpg/1_1546_24_13.jpg  101  156  151  106     P
# 2416  niihau/jpg/1_1546_22_13.jpg  376  327  476  227     P
# 2417  niihau/jpg/1_1546_15_21.jpg  893  528  943  478     P
# 2418  niihau/jpg/1_1546_15_22.jpg   93  528  143  478     P
# 2419  niihau/jpg/1_1546_17_21.jpg  623  531  673  481     P
# 2420  niihau/jpg/1_1546_17_22.jpg   62  256  112  206     P
# 2421  niihau/jpg/1_1546_16_21.jpg  812  884  862  834     P
# 2422  niihau/jpg/1_1546_16_22.jpg   12  884   62  834     P
# 2423  niihau/jpg/1_1546_13_23.jpg  920  679  970  629     P
# 2424  niihau/jpg/1_1546_13_24.jpg  120  679  170  629     P
# 2425  niihau/jpg/1_1547_05_02.jpg  800  903  850  853     P
# 2426  niihau/jpg/1_1547_05_03.jpg    0  903   50  853     P
# 2427  niihau/jpg/1_1547_06_02.jpg  800  103  850   53     P
# 2428  niihau/jpg/1_1547_06_03.jpg    0  103   50   53     P
#
#                                           file_path
# 0     /srv/notebooks/niihau/images/1_1920_06_12.jpg
# 1     /srv/notebooks/niihau/images/1_1920_06_13.jpg
# 2     /srv/notebooks/niihau/images/1_1920_07_13.jpg
# 3     /srv/notebooks/niihau/images/1_1920_07_12.jpg
# 4     /srv/notebooks/niihau/images/1_1920_08_13.jpg
# 5     /srv/notebooks/niihau/images/1_1920_05_11.jpg
# 6     /srv/notebooks/niihau/images/1_1920_06_11.jpg
# 7     /srv/notebooks/niihau/images/1_1920_08_12.jpg
# 8     /srv/notebooks/niihau/images/1_1920_08_14.jpg
# 9     /srv/notebooks/niihau/images/1_1920_07_14.jpg
# 10    /srv/notebooks/niihau/images/1_1920_08_15.jpg
# 11    /srv/notebooks/niihau/images/1_1920_07_15.jpg
# 12    /srv/notebooks/niihau/images/1_1920_09_15.jpg
# 13    /srv/notebooks/niihau/images/1_1920_09_16.jpg
# 14    /srv/notebooks/niihau/images/1_1920_08_16.jpg
# 15    /srv/notebooks/niihau/images/1_1920_07_16.jpg
# 16    /srv/notebooks/niihau/images/1_1920_05_15.jpg
# 17    /srv/notebooks/niihau/images/1_1920_05_16.jpg
# 18    /srv/notebooks/niihau/images/1_1920_06_15.jpg
# 19    /srv/notebooks/niihau/images/1_1920_06_16.jpg
# 20    /srv/notebooks/niihau/images/1_1920_08_17.jpg
# 21    /srv/notebooks/niihau/images/1_1920_09_17.jpg
# 22    /srv/notebooks/niihau/images/1_1920_07_17.jpg
# 23    /srv/notebooks/niihau/images/1_1920_06_17.jpg
# 24    /srv/notebooks/niihau/images/1_1920_10_17.jpg
# 25    /srv/notebooks/niihau/images/1_1920_08_18.jpg
# 26    /srv/notebooks/niihau/images/1_1920_05_22.jpg
# 27    /srv/notebooks/niihau/images/1_1920_06_22.jpg
# 28    /srv/notebooks/niihau/images/2_1747_24_10.jpg
# 29    /srv/notebooks/niihau/images/1_1920_05_23.jpg
# ...                                             ...
# 2399  /srv/notebooks/niihau/images/1_1546_32_04.jpg
# 2400  /srv/notebooks/niihau/images/1_1546_29_04.jpg
# 2401  /srv/notebooks/niihau/images/1_1546_29_05.jpg
# 2402  /srv/notebooks/niihau/images/1_1546_30_04.jpg
# 2403  /srv/notebooks/niihau/images/1_1546_30_05.jpg
# 2404  /srv/notebooks/niihau/images/1_1546_26_07.jpg
# 2405  /srv/notebooks/niihau/images/1_1546_26_08.jpg
# 2406  /srv/notebooks/niihau/images/1_1546_27_07.jpg
# 2407  /srv/notebooks/niihau/images/1_1546_27_08.jpg
# 2408  /srv/notebooks/niihau/images/1_1546_25_09.jpg
# 2409  /srv/notebooks/niihau/images/1_1546_25_11.jpg
# 2410  /srv/notebooks/niihau/images/1_1546_25_12.jpg
# 2411  /srv/notebooks/niihau/images/1_1546_25_10.jpg
# 2412  /srv/notebooks/niihau/images/1_1546_24_12.jpg
# 2413  /srv/notebooks/niihau/images/1_1546_23_12.jpg
# 2414  /srv/notebooks/niihau/images/1_1546_23_13.jpg
# 2415  /srv/notebooks/niihau/images/1_1546_24_13.jpg
# 2416  /srv/notebooks/niihau/images/1_1546_22_13.jpg
# 2417  /srv/notebooks/niihau/images/1_1546_15_21.jpg
# 2418  /srv/notebooks/niihau/images/1_1546_15_22.jpg
# 2419  /srv/notebooks/niihau/images/1_1546_17_21.jpg
# 2420  /srv/notebooks/niihau/images/1_1546_17_22.jpg
# 2421  /srv/notebooks/niihau/images/1_1546_16_21.jpg
# 2422  /srv/notebooks/niihau/images/1_1546_16_22.jpg
# 2423  /srv/notebooks/niihau/images/1_1546_13_23.jpg
# 2424  /srv/notebooks/niihau/images/1_1546_13_24.jpg
# 2425  /srv/notebooks/niihau/images/1_1547_05_02.jpg
# 2426  /srv/notebooks/niihau/images/1_1547_05_03.jpg
# 2427  /srv/notebooks/niihau/images/1_1547_06_02.jpg
# 2428  /srv/notebooks/niihau/images/1_1547_06_03.jpg
#
# [2429 rows x 7 columns]

# %%
##add negative examples

# %%
def download_from_s3(s3_key):
    basename = os.path.basename(s3_key)
    local_file_path = local_tmp_folder.format(basename)
    s3_resource.Bucket(bucket_name).download_file(s3_key, local_file_path)
    return local_file_path

def convert_tif_to_jpeg(tiff_image_path):
    src = rasterio.open(tiff_image_path)
    jpg_path = tiff_image_path.replace(".tif", ".jpg")
    data = src.read()
    profile = src.profile
    result = data.astype(rasterio.uint8, casting='unsafe', copy=False)
    profile.update(driver='jpeg')
    with rasterio.open(jpg_path, 'w', **profile) as dst:
        dst.write(result)
    return jpg_path
                
def upload_to_s3(local_file_path, s3_path):
    s3_client.upload_file(local_file_path, bucket_name, s3_path)

def find_min_xy(coordinates):
    x0 = min([i[0] for i in coordinates])
    x1 = max([i[0] for i in coordinates])
    y0 = min([i[1] for i in coordinates])
    y1 = max([i[1] for i in coordinates])
    return x0,y0,x1,y1


def get_pixel_coordinates(image_path, coordinates):
    driver = gdal.GetDriverByName('GTiff')
    dataset = gdal.Open(image_path)
    band = dataset.GetRasterBand(1)

    cols = dataset.RasterXSize
    rows = dataset.RasterYSize

    transform = dataset.GetGeoTransform()

    xOrigin = transform[0]
    yOrigin = transform[3]
    pixelWidth = transform[1]
    pixelHeight = -transform[5]

    data = band.ReadAsArray(0, 0, cols, rows)

    x0, y0, x1, y1 = coordinates
    x0p = int((x0 - xOrigin) / pixelWidth)
    y0p = int((yOrigin - y0 ) / pixelHeight)
    x1p = int((x1 - xOrigin) / pixelWidth)
    y1p = int((yOrigin - y1 ) / pixelHeight)
    return x0p, y0p, x1p, y1p

# %% [markdown]
# ### Parse geojson

# %%
#download all necessary geojson files:

# %%
import json
from pprint import pprint
#list of all debris annotated from UoH
with open("{}/final_marine_debris_database_NI_UTM4N_boxes.geojson".format(root_folder)) as f:
    geo_json = json.load(f)
len(geo_json['features'])
debris_boxes = geo_json['features']


with open("{}/niihau_tileindex.geojson".format(root_folder)) as f:
    tiles_geo_json = json.load(f)
len(tiles_geo_json['features'])
tiles_features = tiles_geo_json['features']

# %%
debris_boxes[0]
# Out:
# {u'geometry': {u'coordinates': [[[390411.34116614977, 2432815.3680491154],
#     [390412.34116614977, 2432815.3680491154],
#     [390412.34116614977, 2432816.3680491154],
#     [390411.34116614977, 2432816.3680491154],
#     [390411.34116614977, 2432815.3680491154]]],
#   u'type': u'Polygon'},
#  u'properties': {u'comment': None,
#   u'island': u'NI',
#   u'lat': 21.996464,
#   u'long': -160.061616,
#   u'max_size_meters': 0.5,
#   u'max_size_s': u'0.5',
#   u'min_size_meters': 0.01,
#   u'observer': u'AO',
#   u'pt_id': 1,
#   u'segment': 1,
#   u'size': 1,
#   u'type': u'P',
#   u'unique_pt_id': u'NI-001-0001'},
#  u'type': u'Feature'}

# %%
#filter out specific data that we are looking for
target_islands = ["NI"]
objects = ['T','V','N','B','M','P','C']
geo_json_in_search = []
set_of_objs = set()
for d in debris_boxes:
    if d['properties']['type'] in objects and d['properties']['island'] in target_islands:
        geo_json_in_search.append(d)
    set_of_objs.add(d['properties']['type'])
    
print("# of debris :{}".format(len(geo_json_in_search)))
print(set_of_objs)
# Debris categories:
# B = Buoys and floats
# C = Cloth	
# F = Foam 
# L = Line (single pieces of rope, not net)
# M = Metal
# N = Net
# P = Plastic
# T = Tire
# W = Processed wood
# V = Vessel
# O = Other
# Out:
# # of debris :6797
# set([u'C', u'B', u'p', u'F', u'M', u'L', u'O', u'N', u'P', u'T', u'W', u'V'])

# %%
#find corresponding tile
tile_with_debris = []
print("searching {}".format(len(geo_json_in_search)))
# Out:
# searching 6797

# %%
bucket_name = 'hawaii-marine-debris'

s3key_path_template = "niihau/jpg/{}"
downloaded_tile = set()
csv_rows = []

print("Search for tile image based on annotation geojson")
for debris in geo_json_in_search:
    found_debris = False
    target = find_min_xy(debris['geometry']['coordinates'][0])
    for tile in tiles_features:
        x0,y0,x1,y1 = find_min_xy(tile['geometry']['coordinates'][0]) 
        if x0 < target[0] and y0 < target[1] and  x1 > target[2] and y1 > target[3]:
            json = {'label': d['properties']['type'],
             'annotation': target,
             'image_s3':tile['properties']['s3_path'],
            }
            tile_with_debris.append(json)
            print("found--{}".format(len(tile_with_debris)),end='\r')
            found_debris = True
            break
    if found_debris:
        continue
    
print("found--{}".format(len(tile_with_debris)),end='\r')
#just find the first one for now. and let's think about how to deal with second images later.
# Out:
# Search for tile image based on annotation geojson
# found--3171

# %%
tile_with_debris[0]

# %%
try:
    s3_client.head_object(
        Bucket=bucket_name,
        Key='niihau/1_1920/1_1920_06_12.tif_not_exit'
    )
except:
    print("no such file yet")

# %%
print("convert image to JPEG, and convert bounding box to pixels")

for debris in tile_with_debris:
    s3filepath = debris['image_s3'].replace('https://s3-us-west-2.amazonaws.com/hawaii-marine-debris/','')
    tmpfile = "{}/images/niihau/{}".format(root_folder, os.path.basename(s3filepath))

    if tmpfile not in downloaded_tile:
        s3_resource.Bucket(bucket_name).download_file(s3filepath, tmpfile)
        downloaded_tile.add(tmpfile)
    
    pixel_coordinates = get_pixel_coordinates(tmpfile, debris['annotation'])
    jpg_path = convert_tif_to_jpeg(tmpfile)    
    s3_key = s3key_path_template.format(os.path.basename(jpg_path))
    print("Uploaded %s: %s -> %s -> %s" % (len(csv_rows),tmpfile, jpg_path, s3_key), end='\r')
    if tmpfile not in downloaded_tile:
        try:
            s3_client.head_object(
                Bucket=bucket_name,
                Key=s3_key
            )
        except:
            upload_to_s3(jpg_path, s3_key)
    csv_rows.append((s3_key,)+ pixel_coordinates+(debris['label'],))
    #free up storage once it's uploaded
#     os.remove(jpg_path)
#     os.remove(tmpfile)

# %%
len(csv_rows)

# %%
import csv

with open('annotated_marine_debris.csv','wb') as out:
    csv_out=csv.writer(out)
    csv_out.writerow(['s3_key','x0', 'y0','x1','y1', 'label'])
    for row in csv_rows:
        csv_out.writerow(row)

# %%
s3_client.upload_file('annotated_marine_debris.csv', bucket_name, "niihau/annotations.csv")
